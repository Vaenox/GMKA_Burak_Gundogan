# %% [markdown]
# # <center> Güney Marmara ve TRAI
# # <center> Python Veri Analizi Eğitimi
# # <center> Ödev 3

# %% [markdown]
# ### 2021 EUR/TRY kur tablosunun incelenmesi

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px 
import plotly.graph_objects as go
import plotly.subplots as make_subplots

# %% [markdown]
# 1. <i> Yahoo Finance</i> sitesinden 2021 yılına ait EUR/TRY kur değerlerini indiriniz

# %%
kur2021=yf.download("EURTRY=X",start="2021-01-01",end="2021-12-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# 2. Veriyi özet metodları ile inceleyiniz

# %%
kur2021.head()
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2021-01-01  9.08470  9.08470  9.08470  9.08470    9.08470       0
# 2021-01-04  9.11047  9.11154  8.99617  9.10568    9.10568       0
# 2021-01-05  9.09273  9.11239  9.04298  9.08882    9.08882       0
# 2021-01-06  9.08044  9.09500  8.92864  9.08177    9.08177       0
# 2021-01-07  9.00475  9.07176  8.88154  9.00614    9.00614       0

# %%
kur2021.tail()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2021-12-24  12.79533  13.67650  12.51641  12.79752   12.79752       0
# 2021-12-27  12.28318  13.03196  12.16917  12.23056   12.23056       0
# 2021-12-28  12.96156  13.47629  12.88283  13.05254   13.05254       0
# 2021-12-29  13.35232  14.37038  13.31566  13.35252   13.35252       0
# 2021-12-30  14.32090  15.11444  14.05750  14.31055   14.31055       0

# %%
kur2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 260 entries, 2021-01-01 to 2021-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       260 non-null    float64
#  1   High       260 non-null    float64
#  2   Low        260 non-null    float64
#  3   Close      260 non-null    float64
#  4   Adj Close  260 non-null    float64
#  5   Volume     260 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 14.2 KB

# %%
kur2021.shape
# Out:
# (260, 6)

# %%
kur2021.describe()
# Out:
#              Open        High         Low       Close   Adj Close  Volume
# count  260.000000  260.000000  260.000000  260.000000  260.000000   260.0
# mean    10.434622   10.573510   10.347226   10.439140   10.439140     0.0
# std      1.754535    1.940096    1.688033    1.753083    1.753083     0.0
# min      8.386340    8.464750    8.354830    8.387260    8.387260     0.0
# 25%      9.621848    9.695410    9.550110    9.629247    9.629247     0.0
# 50%     10.088800   10.146105   10.047840   10.089370   10.089370     0.0
# 75%     10.439128   10.471000   10.358152   10.442483   10.442483     0.0
# max     18.671040   20.733000   18.657669   18.655109   18.655109     0.0

# %% [markdown]
# 3. Veri temizleme: <br>
# 	• Tabloda sadece "Adj Close" (düzeltilmiş kapanış) sütununu bırakınız.<br>
# 	• "Adj Close" sütununu " Kapanış (TRY)" olarak yeniden adlandırınız.

# %%
kur2021=kur2021["Adj Close"]
kur2021=pd.DataFrame(kur2021)
kur2021.columns=["Kapanış (TRY)"]
kur2021
# Out:
#             Kapanış (TRY)
# Date
# 2021-01-01        9.08470
# 2021-01-04        9.10568
# 2021-01-05        9.08882
# 2021-01-06        9.08177
# 2021-01-07        9.00614
# ...                   ...
# 2021-12-24       12.79752
# 2021-12-27       12.23056
# 2021-12-28       13.05254
# 2021-12-29       13.35252
# 2021-12-30       14.31055
#
# [260 rows x 1 columns]

# %% [markdown]
# 4. Tabloya yeni sütun ekleme:<br>
# 	• Tabloya yeni bir sütun ekleyerek Kapanış (TRY) değerlerini 1 Ocak 2021 tarihindeki kapanış değerine göre normalize ediniz.<br>
# 	• BIST30 endeksinin 2021 yılı boyunca değişimini yorumlayınız.

# %%
normalize=kur2021.iloc[0,0]
kur2021["Normalize"]=kur2021["Kapanış (TRY)"]/normalize

kur2021
# Out:
#             Kapanış (TRY)  Normalize
# Date
# 2021-01-01        9.08470   1.000000
# 2021-01-04        9.10568   1.002309
# 2021-01-05        9.08882   1.000454
# 2021-01-06        9.08177   0.999678
# 2021-01-07        9.00614   0.991353
# ...                   ...        ...
# 2021-12-24       12.79752   1.408689
# 2021-12-27       12.23056   1.346281
# 2021-12-28       13.05254   1.436761
# 2021-12-29       13.35252   1.469781
# 2021-12-30       14.31055   1.575236
#
# [260 rows x 2 columns]

# %% [markdown]
# 5. Veriyi grafik olarak inceleyiniz:<br>
# 	• Tabloyu px grafiği olarak görselleştiriniz.<br>
# 	• Tabloyu go. grafiği olarak görselleştiriniz.

# %%
px.line(kur2021,y="Normalize",
        hover_data={"Normalize":":.2f","Kapanış (TRY)":":.2f"},
        title="2021 Yılı EUR/TL Değişimi",
        labels={"Date":"Tarih","Normalize":"EUR/TL TRY"})

# %%
trace={"mode":"lines","name":"Trace 1","type":"scatter","x":kur2021.index,"y":kur2021["Normalize"]}
data=go.Data=(trace)

go.Figure(data=data)

# %% [markdown]
# ### 2021 ve 2022 değerlerini birlikte inceleme

# %% [markdown]
# 1. <i> Yahoo Finance</i> sitesinden 2022 BIST30 ve EUR/TRY kur değerlerini indiriniz

# %%
veri=yf.download("XU030.IS",start="2022-01-01",end="2022-12-31")
veri
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-03  2039.099976  2109.500000  2032.300049  2109.500000  2109.500000
# 2022-01-04  2128.000000  2176.699951  2109.699951  2157.000000  2157.000000
# 2022-01-05  2158.000000  2213.899902  2145.500000  2212.300049  2212.300049
# 2022-01-06  2196.500000  2239.300049  2180.399902  2219.600098  2219.600098
# 2022-01-07  2235.800049  2260.600098  2206.500000  2256.600098  2256.600098
# ...                 ...          ...          ...          ...          ...
# 2022-12-23  5836.899902  5890.700195  5794.600098  5885.200195  5885.200195
# 2022-12-27  5943.000000  5969.500000  5870.799805  5876.700195  5876.700195
# 2022-12-28  5886.399902  5892.299805  5690.500000  5789.399902  5789.399902
# 2022-12-29  5787.799805  5915.200195  5765.399902  5915.200195  5915.200195
# ...

# %%
kur2022=yf.download("EURTRY=X",start="2022-01-01",end="2022-12-31")
kur2022
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open      High        Low      Close  Adj Close  Volume
# Date
# 2022-01-03  15.177660  15.71496  14.549500  15.189530  15.189530       0
# 2022-01-04  14.678350  15.32340  14.641780  14.763000  14.763000       0
# 2022-01-05  15.073550  15.44457  14.986400  15.071520  15.071520       0
# 2022-01-06  15.432200  15.68613  15.211400  15.445910  15.445910       0
# 2022-01-07  15.486110  15.72783  15.480200  15.434040  15.434040       0
# ...               ...       ...        ...        ...        ...     ...
# 2022-12-26  19.759489  19.87315  19.630131  19.734200  19.734200       0
# 2022-12-27  19.773390  19.96250  19.769699  19.815269  19.815269       0
# 2022-12-28  19.778601  19.97440  19.778601  19.805389  19.805389       0
# 2022-12-29  19.868549  19.96678  19.846180  19.867519  19.867519       0
# 2022-12-30  19.938971  20.02462  19.903080  19.937571  19.937571       0
#
# ...

# %% [markdown]
# 2. Indirdiğiniz verileri 2021 verilerini temizleyip düzenlediğiniz üzere hazırlayınız.

# %%
veri=veri["Adj Close"]
kapanis=pd.DataFrame(veri)
kapanis.columns=["Kapanış (TRY)"]
kapanis
# Out:
#             Kapanış (TRY)
# Date
# 2022-01-03    2109.500000
# 2022-01-04    2157.000000
# 2022-01-05    2212.300049
# 2022-01-06    2219.600098
# 2022-01-07    2256.600098
# ...                   ...
# 2022-12-23    5885.200195
# 2022-12-27    5876.700195
# 2022-12-28    5789.399902
# 2022-12-29    5915.200195
# 2022-12-30    5944.799805
#
# [251 rows x 1 columns]

# %%
normalize=kapanis.iloc[0,0]
kapanis["Normalize"]=kapanis["Kapanış (TRY)"]/normalize

kapanis
# Out:
#             Kapanış (TRY)  Normalize
# Date
# 2022-01-03    2109.500000   1.000000
# 2022-01-04    2157.000000   1.022517
# 2022-01-05    2212.300049   1.048732
# 2022-01-06    2219.600098   1.052193
# 2022-01-07    2256.600098   1.069732
# ...                   ...        ...
# 2022-12-23    5885.200195   2.789856
# 2022-12-27    5876.700195   2.785826
# 2022-12-28    5789.399902   2.744442
# 2022-12-29    5915.200195   2.804077
# 2022-12-30    5944.799805   2.818108
#
# [251 rows x 2 columns]

# %%
kur2022=kur2022["Adj Close"]
kur2022=pd.DataFrame(kur2022)
kur2022.columns=["Kapanış (TRY)"]
kur2022
# Out:
#             Kapanış (TRY)
# Date
# 2022-01-03      15.189530
# 2022-01-04      14.763000
# 2022-01-05      15.071520
# 2022-01-06      15.445910
# 2022-01-07      15.434040
# ...                   ...
# 2022-12-26      19.734200
# 2022-12-27      19.815269
# 2022-12-28      19.805389
# 2022-12-29      19.867519
# 2022-12-30      19.937571
#
# [260 rows x 1 columns]

# %%
normalize=kur2021.iloc[0,0]
kur2022["Normalize"]=kur2022["Kapanış (TRY)"]/normalize

kur2022
# Out:
#             Kapanış (TRY)  Normalize
# Date
# 2022-01-03      15.189530   1.671990
# 2022-01-04      14.763000   1.625040
# 2022-01-05      15.071520   1.659000
# 2022-01-06      15.445910   1.700211
# 2022-01-07      15.434040   1.698905
# ...                   ...        ...
# 2022-12-26      19.734200   2.172246
# 2022-12-27      19.815269   2.181169
# 2022-12-28      19.805389   2.180082
# 2022-12-29      19.867519   2.186921
# 2022-12-30      19.937571   2.194632
#
# [260 rows x 2 columns]

# %%
veri=yf.download("XU030.IS",start="2021-01-01",end="2021-12-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
kapanis1=veri.drop(["Open","High","Low","Close","Volume"],axis=1)

kapanis1.columns=["Kapanış (TRY)"]

kapanis1
# Out:
#             Kapanış (TRY)
# Date
# 2021-01-04    1652.900024
# 2021-01-05    1640.400024
# 2021-01-06    1657.699951
# 2021-01-07    1678.199951
# 2021-01-08    1694.400024
# ...                   ...
# 2021-12-24    2086.800049
# 2021-12-27    2089.399902
# 2021-12-28    2032.900024
# 2021-12-29    2086.300049
# 2021-12-30    2040.199951
#
# [238 rows x 1 columns]

# %%
normalize=kapanis1.iloc[0,0]
kapanis1["Normalize"]=kapanis1["Kapanış (TRY)"]/ normalize
kapanis1
# Out:
#             Kapanış (TRY)  Normalize
# Date
# 2021-01-04    1652.900024   1.000000
# 2021-01-05    1640.400024   0.992438
# 2021-01-06    1657.699951   1.002904
# 2021-01-07    1678.199951   1.015306
# 2021-01-08    1694.400024   1.025107
# ...                   ...        ...
# 2021-12-24    2086.800049   1.262508
# 2021-12-27    2089.399902   1.264081
# 2021-12-28    2032.900024   1.229899
# 2021-12-29    2086.300049   1.262206
# 2021-12-30    2040.199951   1.234315
#
# [238 rows x 2 columns]

# %% [markdown]
# 3. 2021 ve 2022 veri tablolarını tek bir tablo haline getiriniz.

# %%
kurToplam=pd.concat([kur2021,kur2022])
kurToplam
# Out:
#             Kapanış (TRY)  Normalize
# Date
# 2021-01-01       9.084700   1.000000
# 2021-01-04       9.105680   1.002309
# 2021-01-05       9.088820   1.000454
# 2021-01-06       9.081770   0.999678
# 2021-01-07       9.006140   0.991353
# ...                   ...        ...
# 2022-12-26      19.734200   2.172246
# 2022-12-27      19.815269   2.181169
# 2022-12-28      19.805389   2.180082
# 2022-12-29      19.867519   2.186921
# 2022-12-30      19.937571   2.194632
#
# [520 rows x 2 columns]

# %%
bist30Toplam=pd.concat([kapanis1,kapanis])
bist30Toplam
# Out:
#             Kapanış (TRY)  Normalize
# Date
# 2021-01-04    1652.900024   1.000000
# 2021-01-05    1640.400024   0.992438
# 2021-01-06    1657.699951   1.002904
# 2021-01-07    1678.199951   1.015306
# 2021-01-08    1694.400024   1.025107
# ...                   ...        ...
# 2022-12-23    5885.200195   2.789856
# 2022-12-27    5876.700195   2.785826
# 2022-12-28    5789.399902   2.744442
# 2022-12-29    5915.200195   2.804077
# 2022-12-30    5944.799805   2.818108
#
# [489 rows x 2 columns]

# %% [markdown]
# 4. Veriyi grafik olarak inceleyiniz:<br>
# 	• Tabloları px grafiği olarak görselleştiriniz.<br>
# 	• Tabloları go. grafiği olarak görselleştiriniz.<br>
# 	• Tabloları subplots grafiği olarak görselleştiriniz.

# %%
#EUR/TL Tabloları

# %%
px.line(kurToplam,y="Normalize",
        hover_data={"Normalize":":.2f","Kapanış (TRY)":":.2f"},
        title="2021 Yılı EUR/TL Değişimi",
        labels={"Date":"Tarih","Normalize":"EUR/TL TRY"})

# %%
trace={"mode":"lines","name":"Trace 1","x":kurToplam.index,"y":kurToplam["Normalize"]}
data=go.Data=(trace)

go.Figure(data=data)

# %%
#BIST30 Tabloları

# %%
px.line(bist30Toplam,y="Normalize",
        hover_data={"Normalize":":.2f","Kapanış (TRY)":":.2f"},
        title="2021 Yılı BIST30 Endeksi Değişimi",
        labels={"Date":"Tarih","Normalize":"BIST30 Endeksi TRY"})

# %%
trace={"mode":"lines","name":"Trace 1","x":bist30Toplam.index,"y":bist30Toplam["Normalize"]}
data=go.Data=(trace)

go.Figure(data=data)

# %%
fig1=px.line(kurToplam,y="Normalize",
        hover_data={"Normalize":":.2f","Kapanış (TRY)":":.2f"},
        title="2021 Yılı EUR/TL Değişimi",
        labels={"Date":"Tarih","Normalize":"EUR/TL TRY"})





trace={"mode":"lines","name":"Trace 1","x":kurToplam.index,"y":kurToplam["Normalize"]}
data=go.Data=(trace)

fig2=go.Figure(data=data)




fig3=px.line(bist30Toplam,y="Normalize",
        hover_data={"Normalize":":.2f","Kapanış (TRY)":":.2f"},
        title="2021 Yılı BIST30 Endeksi Değişimi",
        labels={"Date":"Tarih","Normalize":"BIST30 Endeksi TRY"})




trace={"mode":"lines","name":"Trace 1","x":kurToplam.index,"y":kurToplam["Normalize"]}
data=go.Data=(trace)

fig4=go.Figure(data=data)

# %%
# subplot yapmayı anlamadım malesef.
